# %% [markdown]
# # Import Dependencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import plotly.express as px
import plotly.graph_objs as go
import numpy as np

# %% [markdown]
# # Global Variables

# %%
JOINT_POSITION_DATA = 'joint_positions_data.csv'
END_EFFECTOR_POSITION_DATA = 'end_effector_positions_data.csv'

# %% [markdown]
# # Joint Positions Visualization

# %%
joint_positions_df = pd.read_csv(JOINT_POSITION_DATA)
joint_positions_df.head()
# Out:
#    PairID Algorithm  Joint1_X  Joint1_Y  Joint1_Z  Joint2_X      Joint2_Y  \
# 0       0       RRT         1         0         0  0.999564 -1.048410e-11
# 1       0       RRT         1         0         0  0.999564  4.681450e-07
# 2       0       RRT         1         0         0  0.999564  1.872610e-06
# 3       0       RRT         1         0         0  0.999564  4.213330e-06
# 4       0       RRT         1         0         0  0.999564  7.490120e-06
#
#    Joint2_Z  Joint3_X      Joint3_Y  ...  Joint4_Z  Joint5_X      Joint5_Y  \
# 0      0.36  0.999564 -1.048410e-11  ...  0.657293  0.702887 -7.146700e-09
# 1      0.36  0.999564  4.681450e-07  ...  0.657571  0.703166  3.187260e-04
# 2      0.36  0.999564  1.872610e-06  ...  0.658403  0.704007  1.271320e-03
# 3      0.36  0.999564  4.213330e-06  ...  0.659785  0.705420  2.846910e-03
# 4      0.36  0.999564  7.490120e-06  ...  0.661709  0.707423  5.027120e-03
#
#    Joint5_Z  Joint6_X      Joint6_Y  Joint6_Z  Joint7_X      Joint7_Y  \
# 0  0.657293  0.375212 -9.432360e-09  0.427882  0.375212 -9.432360e-09
# 1  0.657571  0.375273  5.064360e-04  0.428472  0.375273  5.064360e-04
# 2  0.658403  0.375463  2.024970e-03  0.430240  0.375463  2.024970e-03
# 3  0.659785  0.375798  4.553070e-03  0.433187  0.375798  4.553070e-03
# 4  0.661709  0.376308  8.086110e-03  0.437313  0.376308  8.086110e-03
#
#    Joint7_Z
# 0  0.427882
# 1  0.428472
# 2  0.430240
# 3  0.433187
# 4  0.437313
#
# [5 rows x 23 columns]

# %%
def plot_joint_positions(df):
  # Initialize an empty list to store traces for each joint
  traces = []

  # Define a base color (e.g., blue) and its range of intensity
  base_color = [0, 0, 255]  # Blue color
  min_intensity = 10
  max_intensity = 255

  # Get the total number of rows for gradient coloring
  total_rows = len(df)

  # Iterate over rows in the filtered DataFrame
  for i, (_, row) in enumerate(df.iterrows()):
      x_values = [row[f'Joint{i}_X'] for i in range(1, 8)]
      y_values = [row[f'Joint{i}_Y'] for i in range(1, 8)]
      z_values = [row[f'Joint{i}_Z'] for i in range(1, 8)]

      # print(x_values)

      # Calculate the intensity based on the order of the row
      intensity = min_intensity + (max_intensity - min_intensity) * (i / total_rows)

      # Set the color for the current trace
      color = f'rgb({base_color[0]}, {base_color[1]}, {intensity})'

      trace = go.Scatter3d(
          x=x_values,
          y=y_values,
          z=z_values,
          mode='markers+lines',
          marker=dict(size=4),
          line=dict(width=2, color=color),
          name=f'Row {i}'
      )

      traces.append(trace)

  # Create the layout for the plot
  layout = go.Layout(
      title=f'Joint Angles for PairID {pair_id} - Algorithm {algorithm}',
      scene=dict(
          xaxis_title='X',
          yaxis_title='Y',
          zaxis_title='Z'
      )
  )

  # Create the figure and add traces
  fig = go.Figure(data=traces, layout=layout)

  # Show the interactive plot
  fig.show()

# %%
# Filter the DataFrame for a specific PairID and Algorithm (Change as needed)
pair_id = 0
algorithm = 'RRT'
filtered_df = joint_positions_df[(joint_positions_df['PairID'] == pair_id) & (joint_positions_df['Algorithm'] == algorithm)]

plot_joint_positions(filtered_df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6a17947b-f4f2-4947-bba7-eaa124afcca4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a17947b-f4f2-4947-bba7-eaa124afcca4")) {                    Plotly.newPlot(                        "6a17947b-f4f2-4947-bba7-eaa124afcca4",                        [{"line":{"color":"rgb(0, 0, 10.0)","width":2},"marker":{"size":4},"mode":"markers+lines","name":"Row 0","x":[1,0.999564,0.999564,0.702887,0.702887,0.375212,0.375212],"y":[0,-1.04841e-11,-1.04841e-11,-7.1467e-09,-7.1467e-09,-9.43236e-09,-9.43236e-09],"z":[0,0.36,0.36,0.657293,0.657293,0.427882,0.427882],"type":"scatter3d"},{"line":{"color":"rgb(0, 0, 11.282722513089006)","width":2},"marker":{"size":4},"mode":"markers+lines","name":"Row 1","x":[1,0.999564,0.999564,0.703166,0.703166,0.375273,0.375273],"y":[0,4.68145e-07,4.68145e-07,0.000318726,0.000318726,0.000506436,0.000506436],"z":[0,0.36,0.36,0.657571,0.657571,0.428472,0.428472],"type":"scatter3d"},{"line":{"color":"rgb(0, 0, 12.565445026178011)","width":2},"marker":{"size":4},"mode":"markers+lines","name":"Row 2","x":[1,0.999564,0.999564,0.704007,0.704007,0.375463,0.375463],"y":[0,1.87261e-06,1.87261e-06,0.00127132,0.00127132,0.00202497,0.00202497],"z":[0,0.36,0.36,0.658403,0.658403,0.43024,0.43024],"type":"scatter3d"},{"line":{"color":"rgb(0, 0, 13.848167539267015)","width":2},"marker":{"size":4},"mode":"markers+lines","name":"Row 3","x":[1,0.999564,0.999564,0.70542,0.70542,0.375798,0.375798],"y":[0,4.21333e-06,4.21333e-06,0.00284691,0.00284691,0.00455307,0.00455307],"z":[0,0.36,0.36,0.659785,0.659785,0.433187,0.433187],"type":"scatter3d"},{"line":{"color":"rgb(0, 0, 15.130890052356023)","width":2},"marker":{"size":4},"mode":"markers+lines","name":"Row 4","x":[1,0.999564,0.999564,0.707423,0.707423,0.376308,0.376308],"y":[0,7.49012e-06,7.49012e-06,0.00502712,0.00502712,0.00808611,0.00808611],"z":[0,0.36,0.36,0.661709,0.661709,0.437313,0.437313],"type":"scatter3d"},{"line":{"color":"rgb(0, 0, 16.41361256544503)","width":2},"marker":{"size":4},"mode":"markers+lines","name":"Row 5","x":[1,0.999564,0.999564,0.71004,0.71004,0.377034,0.377034],"y":[0,1.17025e-05,1.17025e-05,0.00778575,0.00778575,0.0126167,0.0126167],"z":[0,0.36,0.36,0.664164,0.664164,0.442616,0.442616],"type":"scatter3d"},{"line":{"color":"rgb(0, 0, 17.69633507853403)","width":2},"marker":{"size":4},"mode":"markers+lines","name":"Row 6","x":[1,0.999564,0.999564,0.713302,0.713302,0.378027,0.378027],"y":[0,1.68494e-05,1.68494e-05,0.0110883,0.0110883,0.0181338,0.0181338],"z":[0,0.36,0.36,0.667134,0.667134,0.449095,0.449095],"type":"scatter3d"},{"line":{"color":"rgb(0, 0, 18.979057591623036)","width":2},"marker":{"size":4},"mode":"markers+lines","name":"Row 7","x":[1,0.999564,0.999564,0.717241,0.717241,0.379351,0.379351],"y":[0,2.29254e-05,2.29254e-05,0.0148891,0.0148891,0.0246179,0.0246179],"z":[0,0.36,0.36,0.670601,0.670601,0.456743,0.456743],"type":"scatter3d"},{"line":{"color":"rgb(0, 0, 20.261780104712045)","width":2},"marker":{"size":4},"mode":"markers+lines","name":"Row 8","x":[1,0.999565,0.999565,0.721533,0.721533,0.380937,0.380937],"y":[0,2.93853e-05,2.93853e-05,0.0188118,0.0188118,0.0314734,0.0314734],"z":[0,0.36,0.36,0.674238,0.674238,0.464872,0.464872],"type":"scatter3d"},{"line":{"color":"rgb(0, 0, 21.544502617801047)","width":2},"marker":{"size":4},"mode":"markers+lines","name":"Row 9","x":[1,0.999565,0.999565,0.725925,0.725925,0.382706,0.382706],"y":[0,3.58388e-05,3.58388e-05,0.0226067,0.0226067,0.0382788,0.0382788],"z":[0,0.36,0.36,0.677823,0.677823,0.472993,0.472993],"type":"scatter3d"},{"line":{"color":"rgb(0, 0, 22.827225130890053)","width":2},"marker":{"size":4},"mode":"markers+lines","name":"Row 10","x":[1,0.999566,0.999566,0.730413,0.730413,0. ...

# %%
# Filter the DataFrame for a specific PairID and Algorithm (Change as needed)
pair_id = 0
algorithm = 'CHOMP'
filtered_df = joint_positions_df[(joint_positions_df['PairID'] == pair_id) & (joint_positions_df['Algorithm'] == algorithm)]

plot_joint_positions(filtered_df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="51add948-8e69-429b-98b6-469402e9fa3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51add948-8e69-429b-98b6-469402e9fa3b")) {                    Plotly.newPlot(                        "51add948-8e69-429b-98b6-469402e9fa3b",                        [{"line":{"color":"rgb(0, 0, 10.0)","width":2},"marker":{"size":4},"mode":"markers+lines","name":"Row 0","x":[1,0.999564,0.999564,0.702893,0.702893,0.375191,0.375191],"y":[0,-5.32505e-09,-5.32505e-09,-3.58698e-06,-3.58698e-06,-4.34471e-05,-4.34471e-05],"z":[0,0.36,0.36,0.657299,0.657299,0.427929,0.427929],"type":"scatter3d"},{"line":{"color":"rgb(0, 0, 11.129032258064516)","width":2},"marker":{"size":4},"mode":"markers+lines","name":"Row 1","x":[1,0.999564,0.999564,0.702887,0.702887,0.374831,0.374831],"y":[0,1.77956e-07,1.77956e-07,0.000120717,0.000120717,0.00069283,0.00069283],"z":[0,0.36,0.36,0.657292,0.657292,0.428427,0.428427],"type":"scatter3d"},{"line":{"color":"rgb(0, 0, 12.258064516129032)","width":2},"marker":{"size":4},"mode":"markers+lines","name":"Row 2","x":[1,0.999564,0.999564,0.702866,0.702866,0.373764,0.373764],"y":[0,7.278e-07,7.278e-07,0.000493661,0.000493661,0.00290185,0.00290185],"z":[0,0.36,0.36,0.657272,0.657272,0.429927,0.429927],"type":"scatter3d"},{"line":{"color":"rgb(0, 0, 13.387096774193548)","width":2},"marker":{"size":4},"mode":"markers+lines","name":"Row
def plot_end_effector_positions(df, base_color, algorithm_name):
    # Initialize arrays for X, Y, and Z coordinates
    x_values = []
    y_values = []
    z_values = []

    # Get the total number of rows for gradient coloring
    total_rows = len(df)

    # Iterate over rows in the DataFrame
    for i, (_, row) in enumerate(df.iterrows()):
        x_values.append(row['X'])
        y_values.append(row['Y'])
        z_values.append(row['Z'])

    # Create a single trace for the algorithm
    trace = go.Scatter3d(
        x=x_values,
        y=y_values,
        z=z_values,
        mode='lines',
        marker=dict(size=4),
        line=dict(width=2, color=f'rgb({base_color[0]}, {base_color[1]}, {base_color[2]})'),
        name=algorithm_name
    )

    return [trace]

# Define base colors for RRT and CHOMP
base_color_rrt = [0, 0, 255]  # Blue for RRT
base_color_chomp = [255, 0, 0]  # Red for CHOMP

# Filter and plot for RRT
pair_id = 3
algorithm = 'RRT'
filtered_df_rrt = end_effector_positions_df[(end_effector_positions_df['PairID'] == pair_id) & (end_effector_positions_df['Algorithm'] == algorithm)]
traces_rrt = plot_end_effector_positions(filtered_df_rrt, base_color_rrt, 'RRT')

# Filter and plot for CHOMP
algorithm = 'CHOMP'
filtered_df_chomp = end_effector_positions_df[(end_effector_positions_df['PairID'] == pair_id) & (end_effector_positions_df['Algorithm'] == algorithm)]
traces_chomp = plot_end_effector_positions(filtered_df_chomp, base_color_chomp, 'CHOMP')

# Combine traces and create a single plot
all_traces = traces_rrt + traces_chomp
layout = go.Layout(
    title=f'End Effector Positions for PairID {pair_id}',
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z'
    )
)
fig = go.Figure(data=all_traces, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a16417b7-1cc8-47ae-87d0-1ed8aa5e5905" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a16417b7-1cc8-47ae-87d0-1ed8aa5e5905")) {                    Plotly.newPlot(                        "a16417b7-1cc8-47ae-87d0-1ed8aa5e5905",                        [{"line":{"color":"rgb(0, 0, 255)","width":2},"marker":{"size":4},"mode":"lines","name":"RRT","x":[0.2212,0.221245,0.221387,0.221643,0.222043,0.222631,0.223406,0.224294,0.225292,0.226404,0.227629,0.228968,0.230422,0.231993,0.233679,0.235482,0.237401,0.239438,0.241591,0.243861,0.246247,0.248749,0.251366,0.254098,0.256944,0.259903,0.262973,0.266154,0.269444,0.272842,0.276346,0.279954,0.283665,0.287476,0.291386,0.295392,0.299491,0.303682,0.307962,0.312328,0.316776,0.321306,0.325912,0.330593,0.335344,0.340164,0.345047,0.349992,0.354994,0.360049,0.365154,0.370306,0.375499,0.380732,0.385998,0.391295,0.396619,0.401964,0.407328,0.412706,0.418094,0.423487,0.428881,0.434273,0.439657,0.44503,0.450387,0.455724,0.461037,0.466322,0.471574,0.476788,0.481962,0.487091,0.492171,0.497197,0.502166,0.507073,0.511916,0.51669,0.521391,0.526015,0.53056,0.535021,0.539394,0.543678,0.547868,0.551961,0.555954,0.559844,0.563628,0.567303,0.570867,0.574317,0.577651,0.580866,0.58396,0.58693,0.